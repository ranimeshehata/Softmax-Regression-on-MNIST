# %% [markdown]
# <a href="https://colab.research.google.com/github/ranimeshehata/Softmax-Regression-on-MNIST/blob/main/Copy_of_softmax_regression_epoch100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Softmax Regression on MNIST</h1>

# %% [markdown]
# <h3>Imports</h3>

# %%
import torch
import time
from torchvision import datasets, transforms
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Subset, ConcatDataset
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
# setting the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# <h3>Preprocessing the data</h3>

# %%
# normalizing the dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# %% [markdown]
# <h3>Downloading the dataset</h3>

# %%
train_val_dataset = datasets.MNIST(root='./dataset', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./dataset', train=False, download=True, transform=transform)
combined_dataset = ConcatDataset([train_val_dataset, test_dataset])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.2MB/s]
# Extracting ./dataset/MNIST/raw/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 493kB/s]
# Extracting ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.89MB/s]
# Extracting ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.05MB/s]
# Extracting ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw

# %%
print(f"Train dataset size: {len(train_val_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(f"Combined dataset size: {len(combined_dataset)}")
# Out:
# Train dataset size: 60000
# Test dataset size: 10000
# Combined dataset size: 70000

# %% [markdown]
# <h3>HyperParameters</h3>

# %%
batch_size = 128   # change between 32, 64, 128, 256
num_classes = 10
input_size = 28 * 28
num_epochs = 100
l2_lambda = 0.0001

# %% [markdown]
# <h3>Splitting the data</h3>

# %%
# calculating split sizes
train_datset_size = int(0.6 * len(combined_dataset))
val_dataset_size = int(0.2 * len(combined_dataset))
test_dataset_size = len(combined_dataset) - train_datset_size - val_dataset_size

# printing split sizes
print(train_datset_size, val_dataset_size, test_dataset_size)
# Out:
# 42000 14000 14000

# %%
# splitting the dataset
train_dataset_idx, temp_dataset_idx = train_test_split(list(range(len(combined_dataset))), train_size=train_datset_size, random_state=5)
val_dataset_idx, test_dataset_idx = train_test_split(temp_dataset_idx, test_size=0.5, random_state=5)

print(len(train_dataset_idx), len(val_dataset_idx), len(test_dataset_idx))
# Out:
# 42000 14000 14000

# %%
# make subset of the dataset based on the split indices
train_dataset = Subset(combined_dataset, train_dataset_idx)
val_dataset = Subset(combined_dataset, val_dataset_idx)
test_dataset = Subset(combined_dataset, test_dataset_idx)

print(len(train_dataset), len(val_dataset), len(test_dataset))
# Out:
# 42000 14000 14000

# %%
# creating dataloaders
train_dataset_loader = DataLoader(train_dataset, batch_size, shuffle=True)
val_dataset_loader = DataLoader(val_dataset, batch_size, shuffle=False)
test_dataset_loader = DataLoader(test_dataset, batch_size, shuffle=False)

print(len(train_dataset_loader), len(val_dataset_loader), len(test_dataset_loader))
# Out:
# 329 110 110

# %%
x, y = next(iter(train_dataset_loader))

print(x.shape)  # [batch_size, channels, height, width]
print(y.shape)
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])

# %% [markdown]
# <h2>Softmax Regression Model</h2>

# %% [markdown]
# <h3>1. Define the softmax regression model</h3>
#
# - Define the main layer, this is the main layer of the softmax regression model, which computes (Wx+b)
# - MNIST images are 28x28 pixels, 10 classes
# ```
# self.linear = torch.nn.Linear(input_size, num_classes)
# ```
# - The forward pass that defines how the input data flows through the model

# %%
class SoftmaxRegressionModel(torch.nn.Module):
    def __init__(self, input_size, num_classes):
        super(SoftmaxRegressionModel, self).__init__()
        self.linear = torch.nn.Linear(input_size, num_classes)

    def forward(self, x): # x is the input = image
        x = x.view(x.size(0), -1)  # Flatten the images from (batch_size, 1, 28, 28) to (batch_size, 784), express each example with a vector(784) instead of matrix 28*28
        return self.linear(x)

# %% [markdown]
# <h3>2. Training the Model</h3>
#
# **First: Initialize model, loss function, and optimizer:**
# - Model: Softmax Regression <br/>
# - Loss Function: Cross-Entropy <br/>
# - Optimizer: Stochastic Gradient Descent (SGD) <br/>
#
# - Training Loop: <br/>
# ```
# for epoch in range(num_epochs):
#     model.train()
# ```
#
# - **y_train** is the ground truth label for the current batch
# - **outputs** is the predicted label for the current batch
#
# - clear the gradients of all optimized variables to prevent accumulation of gradients from previous batches ``` optimizer.zero_grad() ```
#
# - forward pass of the model on the current batch ``` outputs = model(x_train) ```
#
# - compute the loss between the predicted label (outputs) and the ground truth label (y_train) ``` loss = criterion(outputs, y_train) ```
# <hr/>
#
# **Compute Gradients:**
#
# - compute the gradients of the loss with respect to the model parameters ``` loss.backward() ```
# - update the model parameters based on the computed gradients ``` optimizer.step() ```
#
# <hr/>
#
# <h3>3. Evaluating the model on Validation Dataset</h3>
#
# **"The validation results are used to tune hyperparameters and select the best model based on its performance on the validation dataset."**
#
# - **Model Evaluation**: Set the model to evaluation mode using `model.eval()`. This ensures that layers like dropout and batch normalization behave appropriately during validation.
# - **Loss Calculation**: Compute the loss on the validation dataset using the same loss function as used for training.
# - **Accuracy Calculation**: Calculate the accuracy by comparing the predicted labels with the true labels.
# - **No Gradient Calculation**: Use `torch.no_grad()` to disable gradient calculation, which reduces memory consumption and speeds up computation during validation.
# - **Performance Monitoring**: Track the validation loss and accuracy for each epoch to monitor the model's performance over time.
#
# <hr/>
#
# <h3>4. Evaluating the model on Test Dataset</h3>
#
# **"After training and validating the model, we evaluate its performance on the test dataset. This helps us understand how well the model generalizes to unseen data."**
#
# - **Model Evaluation**: Set the model to evaluation mode using `model.eval()`. This ensures that layers like dropout and batch normalization behave appropriately during testing.\n",
# - **No Gradient Calculation**: Use `torch.no_grad()` to disable gradient calculation, which reduces memory consumption and speeds up computation during testing.
# - **Prediction**: Pass the test data through the model to obtain predictions.
# - **Accuracy Calculation**: Calculate the accuracy by comparing the predicted labels with the true labels.
# ``accuracy = accuracy_score(y_true, y_pred) ``
#
# <hr/>
#
# <h3>5. Confusion Matrix for the Test Dataset Predictions</h3>
#
# **"A confusion matrix is a useful tool for evaluating the performance of a classification model. It provides a detailed breakdown of the model's predictions compared to the actual labels. The confusion matrix helps in understanding the types of errors the model is making and which classes are being misclassified."**
#
# - **Generate Confusion Matrix**: Calculate the confusion matrix using the true labels and the predicted labels. This matrix shows the counts of true positive, true negative, false positive, and false negative predictions for each class.
# - **Visualization**: Visualize the confusion matrix using a heatmap to make it easier to interpret. The heatmap provides a color-coded representation of the matrix, where the intensity of the color represents the count of predictions.
#
#
# <hr/>
#
# <h3>6. Visualization & Plotting</h3>
#
# **"Visualization and plotting are essential for understanding the performance of the model during training and evaluation. They help in identifying trends, patterns, and potential issues, helping to make informed decisions about model tuning and improvements."**
#
# - **Training and Validation Loss**: Plot the training and validation loss over epochs to monitor the model's learning process. This helps in identifying issues like overfitting or underfitting.
# - **Training and Validation Accuracy**: Plot the training and validation accuracy over epochs to evaluate the model's performance. This helps in understanding how well the model is generalizing to the validation data.
# - **Learning Rate Comparison**: Plot the training and validation metrics for different learning rates to compare their performance. This helps in identifying the best learning rate for the model.

# %%
dict = {}
results = {}
for lr in [0.01]:
    print(f"Learning rate: {lr} without L2 regularization")
    model = SoftmaxRegressionModel(input_size, num_classes).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    train_losses, train_accuracies, val_losses, val_accuracies = [], [], [], []

    start = time.time()

    for epoch in range(num_epochs):     # loop over the dataset num_epochs times
        print(f"Epoch {epoch+1}/{num_epochs}")
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        train_total = 0

        for batch_idx, (x_train, y_train) in enumerate(train_dataset_loader):
            x_train, y_train = x_train.to(device), y_train.to(device)
            optimizer.zero_grad()

            # outputs = logits = values before softmax, with shape (batch_size, num_classes)
            outputs = model(x_train)
            batch_train_loss = criterion(outputs, y_train)

            # calculate the gradients
            predicted = torch.argmax(outputs, dim=1)
            train_total += y_train.size(0)
            train_correct += (predicted == y_train).sum().item()
            batch_train_loss.backward()     # dl/dwi
            optimizer.step()  # update weights, W = W - lr * gradient
            epoch_train_loss += batch_train_loss.item()   # update loss of current epoch with loss for current batch

        # calculate the average loss and accuracy for the current epoch
        epoch_train_loss /= len(train_dataset_loader)
        train_losses.append(epoch_train_loss)
        train_accuracy = 100 * (train_correct / train_total)
        train_accuracies.append(train_accuracy)

        # Validation loop
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        val_total = 0 # total number of examples in the dataset

        with torch.no_grad():
            for x_val, y_val in val_dataset_loader:
                x_val, y_val = x_val.to(device), y_val.to(device)
                outputs = model(x_val)
                batch_val_loss = criterion(outputs, y_val)
                epoch_val_loss += batch_val_loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += y_val.size(0)
                val_correct += (predicted == y_val).sum().item()

        epoch_val_loss /= len(val_dataset_loader)
        val_losses.append(epoch_val_loss)
        val_accuracy = 100 * (val_correct / val_total)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch+1}/{num_epochs} Training Loss: {epoch_train_loss:.4f}")
        print(f"Epoch {epoch+1}/{num_epochs} Training Accuracy: {train_accuracy:.2f}%")
        print(f"Epoch {epoch+1}/{num_epochs} Validation Loss: {epoch_val_loss:.4f}")
        print(f"Epoch {epoch+1}/{num_epochs} Validation Accuracy: {val_accuracy:.2f}%")
        print("-" * 50)

    end = time.time()
    total_duration = end - start
    print(f"Training time for learning rate {lr}: {total_duration:.2f} seconds without L2 regularization")

    # store the training and validation results for the current learning rate
    dict[lr] = (epoch_train_loss, train_accuracy, epoch_val_loss, val_accuracy)
    results[lr] = {
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'val_losses': val_losses,
    'val_accuracies': val_accuracies,
    'total_duration': total_duration
    }

    # Evaluate the model on the test dataset
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for x_test, y_test in test_dataset_loader:
            x_test, y_test = x_test.to(device), y_test.to(device)
            outputs = model(x_test)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(y_test.cpu().numpy()) # convert to numpy array from tensor
            y_pred.extend(predicted.cpu().numpy())

    # calculate the test accuracy
    accuracy = accuracy_score(y_true, y_pred)
    results[lr]['test_accuracy'] = accuracy * 100
    print(f"Test Accuracy: {accuracy * 100:.2f}% for learning rate: {lr} without L2 regularization")
    print("-" * 50)

    print("Results Summary for learning rate: ", lr, " without L2 regularization")
    print(f"Training Loss: {dict[lr][0]: .4f}")
    print(f"Training Accuracy: {dict[lr][1]: .4f}%")
    print(f"Validation Loss: {dict[lr][2]: .4f}")
    print(f"Validation Accuracy: {dict[lr][3]: .4f}%")
    print(f"Test Accuracy: {results[lr]['test_accuracy']:.2f}%")
    print(f"Total Training Time: {results[lr]['total_duration']:.2f} seconds")
    print("-" * 50)

    # plot the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(num_classes)))
    disp.plot(cmap='viridis', values_format='d')
    plt.title(f"Confusion Matrix for Test Set Predictions (lr={lr}) without L2 regularization")
    plt.show()


    # plot the training and validation loss & accuracy for the current learning rate
    plt.figure(figsize=(12, 10))
    epochs = range(1, num_epochs + 1)

    # plot training and validation loss
    plt.subplot(2, 2, 1)
    plt.title(f"Training and Validation Loss for learning rate: {lr} without L2 regularization")
    plt.plot(epochs, results[lr]['train_losses'], label=f'Training Loss (lr={lr})')
    plt.plot(epochs, results[lr]['val_losses'], label=f'Validation Loss (lr={lr})')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # plot training and validation accuracy
    plt.subplot(2, 2, 2)
    plt.title(f"Training and Validation Accuracy for learning rate: {lr } without L2 regularization")
    plt.plot(epochs, results[lr]['train_accuracies'], label=f'Training Accuracy (lr={lr})')
    plt.plot(epochs, results[lr]['val_accuracies'], label=f'Validation Accuracy (lr={lr})')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Learning rate: 0.01 without L2 regularization
# Epoch 1/100
# Epoch 1/100 Training Loss: 0.8561
# Epoch 1/100 Training Accuracy: 80.15%
# Epoch 1/100 Validation Loss: 0.5529
# Epoch 1/100 Validation Accuracy: 86.03%
# --------------------------------------------------
# Epoch 2/100
# Epoch 2/100 Training Loss: 0.4865
# Epoch 2/100 Training Accuracy: 87.47%
# Epoch 2/100 Validation Loss: 0.4660
# Epoch 2/100 Validation Accuracy: 87.04%
# --------------------------------------------------
# Epoch 3/100
# Epoch 3/100 Training Loss: 0.4230
# Epoch 3/100 Training Accuracy: 88.51%
# Epoch 3/100 Validation Loss: 0.4081
# Epoch 3/100 Validation Accuracy: 88.78%
# --------------------------------------------------
# Epoch 4/100
# Epoch 4/100 Training Loss: 0.3929
# Epoch 4/100 Training Accuracy: 89.23%
# Epoch 4/100 Validation Loss: 0.3894
# Epoch 4/100 Validation Accuracy: 88.91%
# --------------------------------------------------
# Epoch 5/100
# Epoch 5/100 Training Loss: 0.3719
# Epoch 5/100 Training Accuracy: 89.67%
# Epoch 5/100 Validation Loss: 0.3699
# Epoch 5/100 Validation Accuracy: 89.61%
# --------------------------------------------------
# Epoch 6/100
# Epoch 6/100 Training Loss: 0.3582
# Epoch 6/100 Training Accuracy: 89.97%
# Epoch 6/100 Validation Loss: 0.3592
# Epoch 6/100 Validation Accuracy: 89.84%
# --------------------------------------------------
# Epoch 7/100
# Epoch 7/100 Training Loss: 0.3476
# Epoch 7/100 Training Accuracy: 90.24%
# Epoch 7/100 Validation Loss: 0.3477
# Epoch 7/100 Validation Accuracy: 90.13%
# --------------------------------------------------
# Epoch 8/100
# Epoch 8/100 Training Loss: 0.3399
# Epoch 8/100 Training Accuracy: 90.48%
# Epoch 8/100 Validation Loss: 0.3434
# Epoch 8/100 Validation Accuracy: 90.28%
# --------------------------------------------------
# Epoch 9/100
# Epoch 9/100 Training Loss: 0.3335
# Epoch 9/100 Training Accuracy: 90.66%
# Epoch 9/100 Validation Loss: 0.3371
# Epoch 9/100 Validation Accuracy: 90.47%
# --------------------------------------------------
# Epoch 10/100
# Epoch 10/100 Training Loss: 0.3288
# Epoch 10/100 Training Accuracy: 90.69%
# Epoch 10/100 Validation Loss: 0.3366
# Epoch 10/100 Validation Accuracy: 90.49%
# --------------------------------------------------
# Epoch 11/100
# Epoch 11/100 Training Loss: 0.3229
# Epoch 11/100 Training Accuracy: 90.82%
# Epoch 11/100 Validation Loss: 0.3282
# Epoch 11/100 Validation Accuracy: 90.58%
# --------------------------------------------------
# Epoch 12/100
# Epoch 12/100 Training Loss: 0.3186
# Epoch 12/100 Training Accuracy: 90.94%
# Epoch 12/100 Validation Loss: 0.3263
# Epoch 12/100 Validation Accuracy: 90.71%
# --------------------------------------------------
# Epoch 13/100
# Epoch 13/100 Training Loss: 0.3149
# Epoch 13/100 Training Accuracy: 91.00%
# Epoch 13/100 Validation Loss: 0.3214
# Epoch 13/100 Validation Accuracy: 90.81%
# --------------------------------------------------
# Epoch 14/100
# Epoch 14/100 Training Loss: 0.3119
# Epoch 14/100 Training Accuracy: 91.14%
# Epoch 14/100 Validation Loss: 0.3205
# Epoch 14/100 Validation Accuracy: 90.99%
# --------------------------------------------------
# Epoch 15/100
# Epoch 15/100 Training Loss: 0.3110
# Epoch 15/100 Training Accuracy: 91.17%
# Epoch 15/100 Validation Loss: 0.3298
# Epoch 15/100 Validation Accuracy: 90.36%
# --------------------------------------------------
# Epoch 16/100
# Epoch 16/100 Training Loss: 0.3071
# Epoch 16/100 Training Accuracy: 91.28%
# Epoch 16/100 Validation Loss: 0.3200
# Epoch 16/100 Validation Accuracy: 90.77%
# --------------------------------------------------
# Epoch 17/100
# Epoch 17/100 Training Loss: 0.3037
# Epoch 17/100 Training Accuracy: 91.34%
# Epoch 17/100 Validation Loss: 0.3133
# Epoch 17/100 Validation Accuracy: 91.01%
# --------------------------------------------------
# Epoch 18/100
# Epoch 18/100 Training Loss: 0.3014
# Epoch 18/100 Training Accuracy: 91.41%
# Epoch 18/100 Validation Loss: 0.3157
# Epoch 18/100 Validation Accuracy: 90.74%
# --------------------------------------------------
# Epoch 19/100
# Epoch 19/100 Training Loss: 0.3002
# Epoch 19/100 Training Accuracy: 91.45%
# Epoch 19/100 Validation Loss: 0.3160
# Epoch 19/100 Validation Accuracy: 91.09%
# --------------------------------------------------
# Epoch 20/100
# Epoch 20/100 Training Loss: 0.2981
# Epoch 20/100 Training Accuracy: 91.54%
# Epoch 20/100 Validation Loss: 0.3206
# Epoch 20/100 Validation Accuracy: 90.69%
# --------------------------------------------------
# Epoch 21/100
# Epoch 21/100 Training Loss: 0.2972
# Epoch 21/100 Training Accuracy: 91.54%
# Epoch 21/100 Validation Loss: 0.3102
# Epoch 21/100 Validation Accuracy: 90.91%
# --------------------------------------------------
# Epoch 22/100
# Epoch 22/100 Training Loss: 0.2947
# Epoch 22/100 Training Accuracy: 91.58%
# Epoch 22/100 Validation Loss: 0.3080
# Epoch 22/100 Validation Accuracy: 91.16%
# --------------------------------------------------
# Epoch 23/100
# Epoch 23/100 Training Loss: 0.2930
# Epoch 23/100 Training Accuracy: 91.65%
# Epoch 23/100 Validation Loss: 0.3079
# Epoch 23/100 Validation Accuracy: 91.08%
# --------------------------------------------------
# Epoch 24/100
# Epoch 24/100 Training Loss: 0.2912
# Epoch 24/100 Training Accuracy: 91.68%
# Epoch 24/100 Validation Loss: 0.3046
# Epoch 24/100 Validation Accuracy: 91.22%
# --------------------------------------------------
# Epoch 25/100
# Epoch 25/100 Training Loss: 0.2913
# Epoch 25/100 Training Accuracy: 91.71%
# Epoch 25/100 Validation Loss: 0.3045
# Epoch 25/100 Validation Accuracy: 91.15%
# --------------------------------------------------
# Epoch 26/100
# Epoch 26/100 Training Loss: 0.2891
# Epoch 26/100 Training Accuracy: 91.77%
# Epoch 26/100 Validation Loss: 0.3024
# Epoch 26/100 Validation Accuracy: 91.36%
# --------------------------------------------------
# Epoch 27/100
# Epoch 27/100 Training Loss: 0.2880
# Epoch 27/100 Training Accuracy: 91.76%
# Epoch 27/100 Validation Loss: 0.3014
# Epoch 27/100 Validation Accuracy: 91.40%
# --------------------------------------------------
# Epoch 28/100
# Epoch 28/100 Training Loss: 0.2868
# Epoch 28/100 Training Accuracy: 91.79%
# Epoch 28/100 Validation Loss: 0.3019
# Epoch 28/100 Validation Accuracy: 91.35%
# --------------------------------------------------
# Epoch 29/100
# Epoch 29/100 Training Loss: 0.2850
# Epoch 29/100 Training Accuracy: 91.86%
# Epoch 29/100 Validation Loss: 0.2995
# Epoch 29/100 Validation Accuracy: 91.46%
# --------------------------------------------------
# Epoch 30/100
# Epoch 30/100 Training Loss: 0.2846
# Epoch 30/100 Training Accuracy: 91.89%
# Epoch 30/100 Validation Loss: 0.3035
# Epoch 30/100 Validation Accuracy: 91.26%
# --------------------------------------------------
# Epoch 31/100
# Epoch 31/100 Training Loss: 0.2835
# Epoch 31/100 Training Accuracy: 91.95%
# Epoch 31/100 Validation Loss: 0.3032
# Epoch 31/100 Validation Accuracy: 91.06%
# --------------------------------------------------
# Epoch 32/100
# Epoch 32/100 Training Loss: 0.2835
# Epoch 32/100 Training Accuracy: 91.93%
# Epoch 32/100 Validation Loss: 0.2996
# Epoch 32/100 Validation Accuracy: 91.49%
# --------------------------------------------------
# Epoch 33/100
# Epoch 33/100 Training Loss: 0.2815
# Epoch 33/100 Training Accuracy: 91.94%
# Epoch 33/100 Validation Loss: 0.2977
# Epoch 33/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 34/100
# Epoch 34/100 Training Loss: 0.2808
# Epoch 34/100 Training Accuracy: 92.02%
# Epoch 34/100 Validation Loss: 0.3011
# Epoch 34/100 Validation Accuracy: 91.20%
# --------------------------------------------------
# Epoch 35/100
# Epoch 35/100 Training Loss: 0.2795
# Epoch 35/100 Training Accuracy: 92.01%
# Epoch 35/100 Validation Loss: 0.2968
# Epoch 35/100 Validation Accuracy: 91.53%
# --------------------------------------------------
# Epoch 36/100
# Epoch 36/100 Training Loss: 0.2792
# Epoch 36/100 Training Accuracy: 91.99%
# Epoch 36/100 Validation Loss: 0.2980
# Epoch 36/100 Validation Accuracy: 91.34%
# --------------------------------------------------
# Epoch 37/100
# Epoch 37/100 Training Loss: 0.2789
# Epoch 37/100 Training Accuracy: 92.05%
# Epoch 37/100 Validation Loss: 0.2976
# Epoch 37/100 Validation Accuracy: 91.55%
# --------------------------------------------------
# Epoch 38/100
# Epoch 38/100 Training Loss: 0.2776
# Epoch 38/100 Training Accuracy: 92.11%
# Epoch 38/100 Validation Loss: 0.2985
# Epoch 38/100 Validation Accuracy: 91.37%
# --------------------------------------------------
# Epoch 39/100
# Epoch 39/100 Training Loss: 0.2767
# Epoch 39/100 Training Accuracy: 92.15%
# Epoch 39/100 Validation Loss: 0.2950
# Epoch 39/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 40/100
# Epoch 40/100 Training Loss: 0.2758
# Epoch 40/100 Training Accuracy: 92.11%
# Epoch 40/100 Validation Loss: 0.2941
# Epoch 40/100 Validation Accuracy: 91.65%
# --------------------------------------------------
# Epoch 41/100
# Epoch 41/100 Training Loss: 0.2749
# Epoch 41/100 Training Accuracy: 92.19%
# Epoch 41/100 Validation Loss: 0.2944
# Epoch 41/100 Validation Accuracy: 91.46%
# --------------------------------------------------
# Epoch 42/100
# Epoch 42/100 Training Loss: 0.2748
# Epoch 42/100 Training Accuracy: 92.22%
# Epoch 42/100 Validation Loss: 0.2934
# Epoch 42/100 Validation Accuracy: 91.68%
# --------------------------------------------------
# Epoch 43/100
# Epoch 43/100 Training Loss: 0.2758
# Epoch 43/100 Training Accuracy: 92.20%
# Epoch 43/100 Validation Loss: 0.2994
# Epoch 43/100 Validation Accuracy: 91.28%
# --------------------------------------------------
# Epoch 44/100
# Epoch 44/100 Training Loss: 0.2735
# Epoch 44/100 Training Accuracy: 92.24%
# Epoch 44/100 Validation Loss: 0.2930
# Epoch 44/100 Validation Accuracy: 91.64%
# --------------------------------------------------
# Epoch 45/100
# Epoch 45/100 Training Loss: 0.2729
# Epoch 45/100 Training Accuracy: 92.29%
# Epoch 45/100 Validation Loss: 0.2943
# Epoch 45/100 Validation Accuracy: 91.59%
# --------------------------------------------------
# Epoch 46/100
# Epoch 46/100 Training Loss: 0.2730
# Epoch 46/100 Training Accuracy: 92.25%
# Epoch 46/100 Validation Loss: 0.2952
# Epoch 46/100 Validation Accuracy: 91.66%
# --------------------------------------------------
# Epoch 47/100
# Epoch 47/100 Training Loss: 0.2728
# Epoch 47/100 Training Accuracy: 92.24%
# Epoch 47/100 Validation Loss: 0.2931
# Epoch 47/100 Validation Accuracy: 91.61%
# --------------------------------------------------
# Epoch 48/100
# Epoch 48/100 Training Loss: 0.2714
# Epoch 48/100 Training Accuracy: 92.33%
# Epoch 48/100 Validation Loss: 0.2918
# Epoch 48/100 Validation Accuracy: 91.69%
# --------------------------------------------------
# Epoch 49/100
# Epoch 49/100 Training Loss: 0.2713
# Epoch 49/100 Training Accuracy: 92.34%
# Epoch 49/100 Validation Loss: 0.2976
# Epoch 49/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 50/100
# Epoch 50/100 Training Loss: 0.2707
# Epoch 50/100 Training Accuracy: 92.34%
# Epoch 50/100 Validation Loss: 0.2923
# Epoch 50/100 Validation Accuracy: 91.73%
# --------------------------------------------------
# Epoch 51/100
# Epoch 51/100 Training Loss: 0.2698
# Epoch 51/100 Training Accuracy: 92.31%
# Epoch 51/100 Validation Loss: 0.2909
# Epoch 51/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 52/100
# Epoch 52/100 Training Loss: 0.2696
# Epoch 52/100 Training Accuracy: 92.35%
# Epoch 52/100 Validation Loss: 0.2928
# Epoch 52/100 Validation Accuracy: 91.56%
# --------------------------------------------------
# Epoch 53/100
# Epoch 53/100 Training Loss: 0.2691
# Epoch 53/100 Training Accuracy: 92.36%
# Epoch 53/100 Validation Loss: 0.2904
# Epoch 53/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 54/100
# Epoch 54/100 Training Loss: 0.2682
# Epoch 54/100 Training Accuracy: 92.40%
# Epoch 54/100 Validation Loss: 0.2911
# Epoch 54/100 Validation Accuracy: 91.75%
# --------------------------------------------------
# Epoch 55/100
# Epoch 55/100 Training Loss: 0.2679
# Epoch 55/100 Training Accuracy: 92.39%
# Epoch 55/100 Validation Loss: 0.2918
# Epoch 55/100 Validation Accuracy: 91.74%
# --------------------------------------------------
# Epoch 56/100
# Epoch 56/100 Training Loss: 0.2673
# Epoch 56/100 Training Accuracy: 92.41%
# Epoch 56/100 Validation Loss: 0.2905
# Epoch 56/100 Validation Accuracy: 91.74%
# --------------------------------------------------
# Epoch 57/100
# Epoch 57/100 Training Loss: 0.2672
# Epoch 57/100 Training Accuracy: 92.48%
# Epoch 57/100 Validation Loss: 0.2901
# Epoch 57/100 Validation Accuracy: 91.71%
# --------------------------------------------------
# Epoch 58/100
# Epoch 58/100 Training Loss: 0.2671
# Epoch 58/100 Training Accuracy: 92.42%
# Epoch 58/100 Validation Loss: 0.2887
# Epoch 58/100 Validation Accuracy: 91.92%
# --------------------------------------------------
# Epoch 59/100
# Epoch 59/100 Training Loss: 0.2674
# Epoch 59/100 Training Accuracy: 92.48%
# Epoch 59/100 Validation Loss: 0.2908
# Epoch 59/100 Validation Accuracy: 91.80%
# --------------------------------------------------
# Epoch 60/100
# Epoch 60/100 Training Loss: 0.2662
# Epoch 60/100 Training Accuracy: 92.42%
# Epoch 60/100 Validation Loss: 0.2894
# Epoch 60/100 Validation Accuracy: 91.71%
# --------------------------------------------------
# Epoch 61/100
# Epoch 61/100 Training Loss: 0.2652
# Epoch 61/100 Training Accuracy: 92.52%
# Epoch 61/100 Validation Loss: 0.2878
# Epoch 61/100 Validation Accuracy: 91.83%
# --------------------------------------------------
# Epoch 62/100
# Epoch 62/100 Training Loss: 0.2649
# Epoch 62/100 Training Accuracy: 92.56%
# Epoch 62/100 Validation Loss: 0.2879
# Epoch 62/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 63/100
# Epoch 63/100 Training Loss: 0.2659
# Epoch 63/100 Training Accuracy: 92.51%
# Epoch 63/100 Validation Loss: 0.3004
# Epoch 63/100 Validation Accuracy: 91.37%
# --------------------------------------------------
# Epoch 64/100
# Epoch 64/100 Training Loss: 0.2647
# Epoch 64/100 Training Accuracy: 92.50%
# Epoch 64/100 Validation Loss: 0.2895
# Epoch 64/100 Validation Accuracy: 91.70%
# --------------------------------------------------
# Epoch 65/100
# Epoch 65/100 Training Loss: 0.2637
# Epoch 65/100 Training Accuracy: 92.58%
# Epoch 65/100 Validation Loss: 0.2876
# Epoch 65/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 66/100
# Epoch 66/100 Training Loss: 0.2640
# Epoch 66/100 Training Accuracy: 92.54%
# Epoch 66/100 Validation Loss: 0.2957
# Epoch 66/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 67/100
# Epoch 67/100 Training Loss: 0.2635
# Epoch 67/100 Training Accuracy: 92.52%
# Epoch 67/100 Validation Loss: 0.2886
# Epoch 67/100 Validation Accuracy: 91.81%
# --------------------------------------------------
# Epoch 68/100
# Epoch 68/100 Training Loss: 0.2627
# Epoch 68/100 Training Accuracy: 92.64%
# Epoch 68/100 Validation Loss: 0.2876
# Epoch 68/100 Validation Accuracy: 91.95%
# --------------------------------------------------
# Epoch 69/100
# Epoch 69/100 Training Loss: 0.2629
# Epoch 69/100 Training Accuracy: 92.57%
# Epoch 69/100 Validation Loss: 0.2864
# Epoch 69/100 Validation Accuracy: 91.98%
# --------------------------------------------------
# Epoch 70/100
# Epoch 70/100 Training Loss: 0.2621
# Epoch 70/100 Training Accuracy: 92.61%
# Epoch 70/100 Validation Loss: 0.2869
# Epoch 70/100 Validation Accuracy: 91.86%
# --------------------------------------------------
# Epoch 71/100
# Epoch 71/100 Training Loss: 0.2619
# Epoch 71/100 Training Accuracy: 92.60%
# Epoch 71/100 Validation Loss: 0.2877
# Epoch 71/100 Validation Accuracy: 91.81%
# --------------------------------------------------
# Epoch 72/100
# Epoch 72/100 Training Loss: 0.2614
# Epoch 72/100 Training Accuracy: 92.59%
# Epoch 72/100 Validation Loss: 0.2866
# Epoch 72/100 Validation Accuracy: 91.86%
# --------------------------------------------------
# Epoch 73/100
# Epoch 73/100 Training Loss: 0.2609
# Epoch 73/100 Training Accuracy: 92.68%
# Epoch 73/100 Validation Loss: 0.2860
# Epoch 73/100 Validation Accuracy: 91.86%
# --------------------------------------------------
# Epoch 74/100
# Epoch 74/100 Training Loss: 0.2607
# Epoch 74/100 Training Accuracy: 92.61%
# Epoch 74/100 Validation Loss: 0.2867
# Epoch 74/100 Validation Accuracy: 91.90%
# --------------------------------------------------
# Epoch 75/100
# Epoch 75/100 Training Loss: 0.2604
# Epoch 75/100 Training Accuracy: 92.66%
# Epoch 75/100 Validation Loss: 0.2872
# Epoch 75/100 Validation Accuracy: 91.82%
# --------------------------------------------------
# Epoch 76/100
# Epoch 76/100 Training Loss: 0.2607
# Epoch 76/100 Training Accuracy: 92.64%
# Epoch 76/100 Validation Loss: 0.2900
# Epoch 76/100 Validation Accuracy: 91.88%
# --------------------------------------------------
# Epoch 77/100
# Epoch 77/100 Training Loss: 0.2600
# Epoch 77/100 Training Accuracy: 92.62%
# Epoch 77/100 Validation Loss: 0.2867
# Epoch 77/100 Validation Accuracy: 91.90%
# --------------------------------------------------
# Epoch 78/100
# Epoch 78/100 Training Loss: 0.2595
# Epoch 78/100 Training Accuracy: 92.66%
# Epoch 78/100 Validation Loss: 0.2849
# Epoch 78/100 Validation Accuracy: 91.88%
# --------------------------------------------------
# Epoch 79/100
# Epoch 79/100 Training Loss: 0.2596
# Epoch 79/100 Training Accuracy: 92.66%
# Epoch 79/100 Validation Loss: 0.2866
# Epoch 79/100 Validation Accuracy: 92.02%
# --------------------------------------------------
# Epoch 80/100
# Epoch 80/100 Training Loss: 0.2610
# Epoch 80/100 Training Accuracy: 92.67%
# Epoch 80/100 Validation Loss: 0.2871
# Epoch 80/100 Validation Accuracy: 91.87%
# --------------------------------------------------
# Epoch 81/100
# Epoch 81/100 Training Loss: 0.2588
# Epoch 81/100 Training Accuracy: 92.71%
# Epoch 81/100 Validation Loss: 0.2856
# Epoch 81/100 Validation Accuracy: 91.91%
# --------------------------------------------------
# Epoch 82/100
# Epoch 82/100 Training Loss: 0.2585
# Epoch 82/100 Training Accuracy: 92.71%
# Epoch 82/100 Validation Loss: 0.2851
# Epoch 82/100 Validation Accuracy: 91.93%
# --------------------------------------------------
# Epoch 83/100
# Epoch 83/100 Training Loss: 0.2588
# Epoch 83/100 Training Accuracy: 92.70%
# Epoch 83/100 Validation Loss: 0.2956
# Epoch 83/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 84/100
# Epoch 84/100 Training Loss: 0.2579
# Epoch 84/100 Training Accuracy: 92.74%
# Epoch 84/100 Validation Loss: 0.2849
# Epoch 84/100 Validation Accuracy: 91.91%
# --------------------------------------------------
# Epoch 85/100
# Epoch 85/100 Training Loss: 0.2586
# Epoch 85/100 Training Accuracy: 92.66%
# Epoch 85/100 Validation Loss: 0.2859
# Epoch 85/100 Validation Accuracy: 91.98%
# --------------------------------------------------
# Epoch 86/100
# Epoch 86/100 Training Loss: 0.2575
# Epoch 86/100 Training Accuracy: 92.75%
# Epoch 86/100 Validation Loss: 0.2885
# Epoch 86/100 Validation Accuracy: 91.88%
# --------------------------------------------------
# Epoch 87/100
# Epoch 87/100 Training Loss: 0.2576
# Epoch 87/100 Training Accuracy: 92.78%
# Epoch 87/100 Validation Loss: 0.2872
# Epoch 87/100 Validation Accuracy: 91.84%
# --------------------------------------------------
# Epoch 88/100
# Epoch 88/100 Training Loss: 0.2580
# Epoch 88/100 Training Accuracy: 92.76%
# Epoch 88/100 Validation Loss: 0.2868
# Epoch 88/100 Validation Accuracy: 91.88%
# --------------------------------------------------
# Epoch 89/100
# Epoch 89/100 Training Loss: 0.2569
# Epoch 89/100 Training Accuracy: 92.75%
# Epoch 89/100 Validation Loss: 0.2889
# Epoch 89/100 Validation Accuracy: 91.78%
# --------------------------------------------------
# Epoch 90/100
# Epoch 90/100 Training Loss: 0.2568
# Epoch 90/100 Training Accuracy: 92.74%
# Epoch 90/100 Validation Loss: 0.2844
# Epoch 90/100 Validation Accuracy: 91.96%
# --------------------------------------------------
# Epoch 91/100
# Epoch 91/100 Training Loss: 0.2566
# Epoch 91/100 Training Accuracy: 92.83%
# Epoch 91/100 Validation Loss: 0.2861
# Epoch 91/100 Validation Accuracy: 91.96%
# --------------------------------------------------
# Epoch 92/100
# Epoch 92/100 Training Loss: 0.2562
# Epoch 92/100 Training Accuracy: 92.78%
# Epoch 92/100 Validation Loss: 0.2862
# Epoch 92/100 Validation Accuracy: 91.94%
# --------------------------------------------------
# Epoch 93/100
# Epoch 93/100 Training Loss: 0.2566
# Epoch 93/100 Training Accuracy: 92.76%
# Epoch 93/100 Validation Loss: 0.2847
# Epoch 93/100 Validation Accuracy: 91.95%
# --------------------------------------------------
# Epoch 94/100
# Epoch 94/100 Training Loss: 0.2554
# Epoch 94/100 Training Accuracy: 92.81%
# Epoch 94/100 Validation Loss: 0.2844
# Epoch 94/100 Validation Accuracy: 91.99%
# --------------------------------------------------
# Epoch 95/100
# Epoch 95/100 Training Loss: 0.2562
# Epoch 95/100 Training Accuracy: 92.78%
# Epoch 95/100 Validation Loss: 0.2931
# Epoch 95/100 Validation Accuracy: 91.60%
# --------------------------------------------------
# Epoch 96/100
# Epoch 96/100 Training Loss: 0.2565
# Epoch 96/100 Training Accuracy: 92.86%
# Epoch 96/100 Validation Loss: 0.2908
# Epoch 96/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 97/100
# Epoch 97/100 Training Loss: 0.2552
# Epoch 97/100 Training Accuracy: 92.80%
# Epoch 97/100 Validation Loss: 0.2839
# Epoch 97/100 Validation Accuracy: 92.11%
# --------------------------------------------------
# Epoch 98/100
# Epoch 98/100 Training Loss: 0.2549
# Epoch 98/100 Training Accuracy: 92.81%
# Epoch 98/100 Validation Loss: 0.2862
# Epoch 98/100 Validation Accuracy: 91.92%
# --------------------------------------------------
# Epoch 99/100
# Epoch 99/100 Training Loss: 0.2546
# Epoch 99/100 Training Accuracy: 92.82%
# Epoch 99/100 Validation Loss: 0.2844
# Epoch 99/100 Validation Accuracy: 92.03%
# --------------------------------------------------
# Epoch 100/100
# Epoch 100/100 Training Loss: 0.2543
# Epoch 100/100 Training Accuracy: 92.86%
# Epoch 100/100 Validation Loss: 0.2866
# Epoch 100/100 Validation Accuracy: 92.09%
# --------------------------------------------------
# Training time for learning rate 0.01: 1468.26 seconds without L2 regularization
# Test Accuracy: 91.85% for learning rate: 0.01 without L2 regularization
# --------------------------------------------------
# Results Summary for learning rate:  0.01  without L2 regularization
# Training Loss:  0.2543
# Training Accuracy:  92.8571%
# Validation Loss:  0.2866
# Validation Accuracy:  92.0929%
# Test Accuracy: 91.85%
# Total Training Time: 1468.26 seconds
# --------------------------------------------------

# %% [markdown]
# <h2>Results Summary</h2>

# %%
print("Final Results for all learning rates without L2 Reqularization:")
for lr in [0.01]:
    print(f"learning_rate = {lr}")
    print(f"Training Loss: {dict[lr][0]: .4f}")
    print(f"Training Accuracy: {dict[lr][1]: .4f}%")
    print(f"Validation Loss: {dict[lr][2]: .4f}")
    print(f"Validation Accuracy: {dict[lr][3]: .4f}%")
    print(f"Test Accuracy: {results[lr]['test_accuracy']:.2f}%")
    print(f"Total Training Time: {results[lr]['total_duration']:.2f} seconds")

    print("-" * 50)
# Out:
# Final Results for all learning rates without L2 Reqularization:
# learning_rate = 0.01
# Training Loss:  0.2543
# Training Accuracy:  92.8571%
# Validation Loss:  0.2866
# Validation Accuracy:  92.0929%
# Test Accuracy: 91.85%
# Total Training Time: 1468.26 seconds
# --------------------------------------------------

# %% [markdown]
# <h2>Best Learning Rate</h2>

# %%
# Find the best learning rate based on the test accuracy
best_lr = None
best_accuracy = 0

for lr in results.keys():
    if results[lr]['test_accuracy'] > best_accuracy:
        best_accuracy = results[lr]['test_accuracy']
        best_lr = lr

print(f"Best Learning Rate: {best_lr} with Test Accuracy: {best_accuracy:.2f}% without L2 regularization")
# Out:
# Best Learning Rate: 0.01 with Test Accuracy: 91.85% without L2 regularization

# %% [markdown]
# <h2>Adding L2 Reqularization</h2>
#
# with lambda = 0.0001

# %%
dict = {}
results = {}
for lr in [0.01]:
    print(f"Learning rate: {lr} with L2 regularization")
    model = SoftmaxRegressionModel(input_size, num_classes).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l2_lambda)
    train_losses, train_accuracies, val_losses, val_accuracies = [], [], [], []

    start = time.time()

    for epoch in range(num_epochs):     # loop over the dataset num_epochs times
        print(f"Epoch {epoch+1}/{num_epochs}")
        model.train()
        epoch_train_loss = 0.0
        train_correct = 0
        train_total = 0

        for batch_idx, (x_train, y_train) in enumerate(train_dataset_loader):
            x_train, y_train = x_train.to(device), y_train.to(device)
            optimizer.zero_grad()

            # outputs = logits = values before softmax, with shape (batch_size, num_classes)
            outputs = model(x_train)
            batch_train_loss = criterion(outputs, y_train)

            # calculate the gradients
            predicted = torch.argmax(outputs, dim=1)
            train_total += y_train.size(0)
            train_correct += (predicted == y_train).sum().item()
            batch_train_loss.backward()     # dl/dwi
            optimizer.step()  # update weights, W = W - lr * gradient
            epoch_train_loss += batch_train_loss.item()   # update loss of current epoch with loss for current batch

        # calculate the average loss and accuracy for the current epoch
        epoch_train_loss /= len(train_dataset_loader)
        train_losses.append(epoch_train_loss)
        train_accuracy = 100 * (train_correct / train_total)
        train_accuracies.append(train_accuracy)

        # Validation loop
        model.eval()
        epoch_val_loss = 0.0
        val_correct = 0
        val_total = 0 # total number of examples in the dataset

        with torch.no_grad():
            for x_val, y_val in val_dataset_loader:
                x_val, y_val = x_val.to(device), y_val.to(device)
                outputs = model(x_val)
                batch_val_loss = criterion(outputs, y_val)
                epoch_val_loss += batch_val_loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += y_val.size(0)
                val_correct += (predicted == y_val).sum().item()

        epoch_val_loss /= len(val_dataset_loader)
        val_losses.append(epoch_val_loss)
        val_accuracy = 100 * (val_correct / val_total)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch+1}/{num_epochs} Training Loss: {epoch_train_loss:.4f}")
        print(f"Epoch {epoch+1}/{num_epochs} Training Accuracy: {train_accuracy:.2f}%")
        print(f"Epoch {epoch+1}/{num_epochs} Validation Loss: {epoch_val_loss:.4f}")
        print(f"Epoch {epoch+1}/{num_epochs} Validation Accuracy: {val_accuracy:.2f}%")
        print("-" * 50)

    end = time.time()
    total_duration = end - start
    print(f"Training time for learning rate {lr}: {total_duration:.2f} seconds with L2 regularization")

    # store the training and validation results for the current learning rate
    dict[lr] = (epoch_train_loss, train_accuracy, epoch_val_loss, val_accuracy)
    results[lr] = {
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'val_losses': val_losses,
    'val_accuracies': val_accuracies,
    'total_duration': total_duration
    }

    # Evaluate the model on the test dataset
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for x_test, y_test in test_dataset_loader:
            x_test, y_test = x_test.to(device), y_test.to(device)
            outputs = model(x_test)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(y_test.cpu().numpy()) # convert to numpy array from tensor
            y_pred.extend(predicted.cpu().numpy())

    # calculate the test accuracy
    accuracy = accuracy_score(y_true, y_pred)
    results[lr]['test_accuracy'] = accuracy * 100
    print(f"Test Accuracy: {accuracy * 100:.2f}% for learning rate: {lr} with L2 regularization")
    print("-" * 50)

    print("Results Summary for learning rate: ", lr, " with L2 regularization")
    print(f"Training Loss: {dict[lr][0]: .4f}")
    print(f"Training Accuracy: {dict[lr][1]: .4f}%")
    print(f"Validation Loss: {dict[lr][2]: .4f}")
    print(f"Validation Accuracy: {dict[lr][3]: .4f}%")
    print(f"Test Accuracy: {results[lr]['test_accuracy']:.2f}%")
    print(f"Total Training Time: {results[lr]['total_duration']:.2f} seconds")
    print("-" * 50)

    # plot the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(num_classes)))
    disp.plot(cmap='viridis', values_format='d')
    plt.title(f"Confusion Matrix for Test Set Predictions (lr={lr}) with L2 regularization")
    plt.show()


    # plot the training and validation loss & accuracy for the current learning rate
    plt.figure(figsize=(12, 10))
    epochs = range(1, num_epochs + 1)

    # plot training and validation loss
    plt.subplot(2, 2, 1)
    plt.title(f"Training and Validation Loss for learning rate: {lr} with L2 regularization")
    plt.plot(epochs, results[lr]['train_losses'], label=f'Training Loss (lr={lr})')
    plt.plot(epochs, results[lr]['val_losses'], label=f'Validation Loss (lr={lr})')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # plot training and validation accuracy
    plt.subplot(2, 2, 2)
    plt.title(f"Training and Validation Accuracy for learning rate: {lr} with L2 regularization")
    plt.plot(epochs, results[lr]['train_accuracies'], label=f'Training Accuracy (lr={lr})')
    plt.plot(epochs, results[lr]['val_accuracies'], label=f'Validation Accuracy (lr={lr})')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Learning rate: 0.01 with L2 regularization
# Epoch 1/100
# Epoch 1/100 Training Loss: 0.8509
# Epoch 1/100 Training Accuracy: 80.13%
# Epoch 1/100 Validation Loss: 0.5622
# Epoch 1/100 Validation Accuracy: 84.86%
# --------------------------------------------------
# Epoch 2/100
# Epoch 2/100 Training Loss: 0.4855
# Epoch 2/100 Training Accuracy: 87.35%
# Epoch 2/100 Validation Loss: 0.4565
# Epoch 2/100 Validation Accuracy: 87.92%
# --------------------------------------------------
# Epoch 3/100
# Epoch 3/100 Training Loss: 0.4225
# Epoch 3/100 Training Accuracy: 88.54%
# Epoch 3/100 Validation Loss: 0.4202
# Epoch 3/100 Validation Accuracy: 88.76%
# --------------------------------------------------
# Epoch 4/100
# Epoch 4/100 Training Loss: 0.3911
# Epoch 4/100 Training Accuracy: 89.25%
# Epoch 4/100 Validation Loss: 0.3861
# Epoch 4/100 Validation Accuracy: 89.27%
# --------------------------------------------------
# Epoch 5/100
# Epoch 5/100 Training Loss: 0.3717
# Epoch 5/100 Training Accuracy: 89.68%
# Epoch 5/100 Validation Loss: 0.3668
# Epoch 5/100 Validation Accuracy: 89.65%
# --------------------------------------------------
# Epoch 6/100
# Epoch 6/100 Training Loss: 0.3588
# Epoch 6/100 Training Accuracy: 90.07%
# Epoch 6/100 Validation Loss: 0.3583
# Epoch 6/100 Validation Accuracy: 90.12%
# --------------------------------------------------
# Epoch 7/100
# Epoch 7/100 Training Loss: 0.3474
# Epoch 7/100 Training Accuracy: 90.31%
# Epoch 7/100 Validation Loss: 0.3498
# Epoch 7/100 Validation Accuracy: 89.91%
# --------------------------------------------------
# Epoch 8/100
# Epoch 8/100 Training Loss: 0.3391
# Epoch 8/100 Training Accuracy: 90.45%
# Epoch 8/100 Validation Loss: 0.3442
# Epoch 8/100 Validation Accuracy: 90.11%
# --------------------------------------------------
# Epoch 9/100
# Epoch 9/100 Training Loss: 0.3324
# Epoch 9/100 Training Accuracy: 90.62%
# Epoch 9/100 Validation Loss: 0.3364
# Epoch 9/100 Validation Accuracy: 90.56%
# --------------------------------------------------
# Epoch 10/100
# Epoch 10/100 Training Loss: 0.3271
# Epoch 10/100 Training Accuracy: 90.80%
# Epoch 10/100 Validation Loss: 0.3319
# Epoch 10/100 Validation Accuracy: 90.65%
# --------------------------------------------------
# Epoch 11/100
# Epoch 11/100 Training Loss: 0.3223
# Epoch 11/100 Training Accuracy: 90.87%
# Epoch 11/100 Validation Loss: 0.3295
# Epoch 11/100 Validation Accuracy: 90.56%
# --------------------------------------------------
# Epoch 12/100
# Epoch 12/100 Training Loss: 0.3192
# Epoch 12/100 Training Accuracy: 91.00%
# Epoch 12/100 Validation Loss: 0.3253
# Epoch 12/100 Validation Accuracy: 90.71%
# --------------------------------------------------
# Epoch 13/100
# Epoch 13/100 Training Loss: 0.3146
# Epoch 13/100 Training Accuracy: 91.10%
# Epoch 13/100 Validation Loss: 0.3250
# Epoch 13/100 Validation Accuracy: 90.87%
# --------------------------------------------------
# Epoch 14/100
# Epoch 14/100 Training Loss: 0.3114
# Epoch 14/100 Training Accuracy: 91.10%
# Epoch 14/100 Validation Loss: 0.3198
# Epoch 14/100 Validation Accuracy: 90.77%
# --------------------------------------------------
# Epoch 15/100
# Epoch 15/100 Training Loss: 0.3083
# Epoch 15/100 Training Accuracy: 91.24%
# Epoch 15/100 Validation Loss: 0.3187
# Epoch 15/100 Validation Accuracy: 90.86%
# --------------------------------------------------
# Epoch 16/100
# Epoch 16/100 Training Loss: 0.3056
# Epoch 16/100 Training Accuracy: 91.35%
# Epoch 16/100 Validation Loss: 0.3170
# Epoch 16/100 Validation Accuracy: 90.91%
# --------------------------------------------------
# Epoch 17/100
# Epoch 17/100 Training Loss: 0.3037
# Epoch 17/100 Training Accuracy: 91.39%
# Epoch 17/100 Validation Loss: 0.3136
# Epoch 17/100 Validation Accuracy: 90.93%
# --------------------------------------------------
# Epoch 18/100
# Epoch 18/100 Training Loss: 0.3023
# Epoch 18/100 Training Accuracy: 91.46%
# Epoch 18/100 Validation Loss: 0.3114
# Epoch 18/100 Validation Accuracy: 91.07%
# --------------------------------------------------
# Epoch 19/100
# Epoch 19/100 Training Loss: 0.2990
# Epoch 19/100 Training Accuracy: 91.46%
# Epoch 19/100 Validation Loss: 0.3105
# Epoch 19/100 Validation Accuracy: 91.04%
# --------------------------------------------------
# Epoch 20/100
# Epoch 20/100 Training Loss: 0.2984
# Epoch 20/100 Training Accuracy: 91.53%
# Epoch 20/100 Validation Loss: 0.3118
# Epoch 20/100 Validation Accuracy: 91.04%
# --------------------------------------------------
# Epoch 21/100
# Epoch 21/100 Training Loss: 0.2967
# Epoch 21/100 Training Accuracy: 91.59%
# Epoch 21/100 Validation Loss: 0.3134
# Epoch 21/100 Validation Accuracy: 91.01%
# --------------------------------------------------
# Epoch 22/100
# Epoch 22/100 Training Loss: 0.2946
# Epoch 22/100 Training Accuracy: 91.61%
# Epoch 22/100 Validation Loss: 0.3065
# Epoch 22/100 Validation Accuracy: 91.24%
# --------------------------------------------------
# Epoch 23/100
# Epoch 23/100 Training Loss: 0.2922
# Epoch 23/100 Training Accuracy: 91.64%
# Epoch 23/100 Validation Loss: 0.3047
# Epoch 23/100 Validation Accuracy: 91.31%
# --------------------------------------------------
# Epoch 24/100
# Epoch 24/100 Training Loss: 0.2912
# Epoch 24/100 Training Accuracy: 91.71%
# Epoch 24/100 Validation Loss: 0.3100
# Epoch 24/100 Validation Accuracy: 91.21%
# --------------------------------------------------
# Epoch 25/100
# Epoch 25/100 Training Loss: 0.2897
# Epoch 25/100 Training Accuracy: 91.69%
# Epoch 25/100 Validation Loss: 0.3034
# Epoch 25/100 Validation Accuracy: 91.34%
# --------------------------------------------------
# Epoch 26/100
# Epoch 26/100 Training Loss: 0.2882
# Epoch 26/100 Training Accuracy: 91.76%
# Epoch 26/100 Validation Loss: 0.3032
# Epoch 26/100 Validation Accuracy: 91.34%
# --------------------------------------------------
# Epoch 27/100
# Epoch 27/100 Training Loss: 0.2875
# Epoch 27/100 Training Accuracy: 91.82%
# Epoch 27/100 Validation Loss: 0.3026
# Epoch 27/100 Validation Accuracy: 91.38%
# --------------------------------------------------
# Epoch 28/100
# Epoch 28/100 Training Loss: 0.2870
# Epoch 28/100 Training Accuracy: 91.85%
# Epoch 28/100 Validation Loss: 0.3043
# Epoch 28/100 Validation Accuracy: 91.34%
# --------------------------------------------------
# Epoch 29/100
# Epoch 29/100 Training Loss: 0.2856
# Epoch 29/100 Training Accuracy: 91.85%
# Epoch 29/100 Validation Loss: 0.3001
# Epoch 29/100 Validation Accuracy: 91.44%
# --------------------------------------------------
# Epoch 30/100
# Epoch 30/100 Training Loss: 0.2851
# Epoch 30/100 Training Accuracy: 91.99%
# Epoch 30/100 Validation Loss: 0.3060
# Epoch 30/100 Validation Accuracy: 91.39%
# --------------------------------------------------
# Epoch 31/100
# Epoch 31/100 Training Loss: 0.2843
# Epoch 31/100 Training Accuracy: 92.02%
# Epoch 31/100 Validation Loss: 0.3009
# Epoch 31/100 Validation Accuracy: 91.44%
# --------------------------------------------------
# Epoch 32/100
# Epoch 32/100 Training Loss: 0.2822
# Epoch 32/100 Training Accuracy: 91.97%
# Epoch 32/100 Validation Loss: 0.3000
# Epoch 32/100 Validation Accuracy: 91.44%
# --------------------------------------------------
# Epoch 33/100
# Epoch 33/100 Training Loss: 0.2815
# Epoch 33/100 Training Accuracy: 91.98%
# Epoch 33/100 Validation Loss: 0.2983
# Epoch 33/100 Validation Accuracy: 91.37%
# --------------------------------------------------
# Epoch 34/100
# Epoch 34/100 Training Loss: 0.2804
# Epoch 34/100 Training Accuracy: 92.06%
# Epoch 34/100 Validation Loss: 0.2985
# Epoch 34/100 Validation Accuracy: 91.34%
# --------------------------------------------------
# Epoch 35/100
# Epoch 35/100 Training Loss: 0.2799
# Epoch 35/100 Training Accuracy: 92.05%
# Epoch 35/100 Validation Loss: 0.2984
# Epoch 35/100 Validation Accuracy: 91.43%
# --------------------------------------------------
# Epoch 36/100
# Epoch 36/100 Training Loss: 0.2789
# Epoch 36/100 Training Accuracy: 92.11%
# Epoch 36/100 Validation Loss: 0.2999
# Epoch 36/100 Validation Accuracy: 91.41%
# --------------------------------------------------
# Epoch 37/100
# Epoch 37/100 Training Loss: 0.2781
# Epoch 37/100 Training Accuracy: 92.15%
# Epoch 37/100 Validation Loss: 0.2981
# Epoch 37/100 Validation Accuracy: 91.40%
# --------------------------------------------------
# Epoch 38/100
# Epoch 38/100 Training Loss: 0.2779
# Epoch 38/100 Training Accuracy: 92.14%
# Epoch 38/100 Validation Loss: 0.2963
# Epoch 38/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 39/100
# Epoch 39/100 Training Loss: 0.2765
# Epoch 39/100 Training Accuracy: 92.10%
# Epoch 39/100 Validation Loss: 0.2958
# Epoch 39/100 Validation Accuracy: 91.72%
# --------------------------------------------------
# Epoch 40/100
# Epoch 40/100 Training Loss: 0.2765
# Epoch 40/100 Training Accuracy: 92.13%
# Epoch 40/100 Validation Loss: 0.2981
# Epoch 40/100 Validation Accuracy: 91.68%
# --------------------------------------------------
# Epoch 41/100
# Epoch 41/100 Training Loss: 0.2764
# Epoch 41/100 Training Accuracy: 92.14%
# Epoch 41/100 Validation Loss: 0.2954
# Epoch 41/100 Validation Accuracy: 91.51%
# --------------------------------------------------
# Epoch 42/100
# Epoch 42/100 Training Loss: 0.2749
# Epoch 42/100 Training Accuracy: 92.22%
# Epoch 42/100 Validation Loss: 0.2946
# Epoch 42/100 Validation Accuracy: 91.62%
# --------------------------------------------------
# Epoch 43/100
# Epoch 43/100 Training Loss: 0.2743
# Epoch 43/100 Training Accuracy: 92.20%
# Epoch 43/100 Validation Loss: 0.2949
# Epoch 43/100 Validation Accuracy: 91.66%
# --------------------------------------------------
# Epoch 44/100
# Epoch 44/100 Training Loss: 0.2737
# Epoch 44/100 Training Accuracy: 92.24%
# Epoch 44/100 Validation Loss: 0.2958
# Epoch 44/100 Validation Accuracy: 91.44%
# --------------------------------------------------
# Epoch 45/100
# Epoch 45/100 Training Loss: 0.2740
# Epoch 45/100 Training Accuracy: 92.23%
# Epoch 45/100 Validation Loss: 0.2951
# Epoch 45/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 46/100
# Epoch 46/100 Training Loss: 0.2722
# Epoch 46/100 Training Accuracy: 92.22%
# Epoch 46/100 Validation Loss: 0.2927
# Epoch 46/100 Validation Accuracy: 91.84%
# --------------------------------------------------
# Epoch 47/100
# Epoch 47/100 Training Loss: 0.2716
# Epoch 47/100 Training Accuracy: 92.31%
# Epoch 47/100 Validation Loss: 0.2929
# Epoch 47/100 Validation Accuracy: 91.69%
# --------------------------------------------------
# Epoch 48/100
# Epoch 48/100 Training Loss: 0.2729
# Epoch 48/100 Training Accuracy: 92.24%
# Epoch 48/100 Validation Loss: 0.2966
# Epoch 48/100 Validation Accuracy: 91.61%
# --------------------------------------------------
# Epoch 49/100
# Epoch 49/100 Training Loss: 0.2722
# Epoch 49/100 Training Accuracy: 92.29%
# Epoch 49/100 Validation Loss: 0.2965
# Epoch 49/100 Validation Accuracy: 91.73%
# --------------------------------------------------
# Epoch 50/100
# Epoch 50/100 Training Loss: 0.2702
# Epoch 50/100 Training Accuracy: 92.30%
# Epoch 50/100 Validation Loss: 0.2923
# Epoch 50/100 Validation Accuracy: 91.84%
# --------------------------------------------------
# Epoch 51/100
# Epoch 51/100 Training Loss: 0.2701
# Epoch 51/100 Training Accuracy: 92.29%
# Epoch 51/100 Validation Loss: 0.2915
# Epoch 51/100 Validation Accuracy: 91.89%
# --------------------------------------------------
# Epoch 52/100
# Epoch 52/100 Training Loss: 0.2694
# Epoch 52/100 Training Accuracy: 92.33%
# Epoch 52/100 Validation Loss: 0.2912
# Epoch 52/100 Validation Accuracy: 91.69%
# --------------------------------------------------
# Epoch 53/100
# Epoch 53/100 Training Loss: 0.2691
# Epoch 53/100 Training Accuracy: 92.42%
# Epoch 53/100 Validation Loss: 0.2913
# Epoch 53/100 Validation Accuracy: 91.79%
# --------------------------------------------------
# Epoch 54/100
# Epoch 54/100 Training Loss: 0.2682
# Epoch 54/100 Training Accuracy: 92.40%
# Epoch 54/100 Validation Loss: 0.2896
# Epoch 54/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 55/100
# Epoch 55/100 Training Loss: 0.2688
# Epoch 55/100 Training Accuracy: 92.40%
# Epoch 55/100 Validation Loss: 0.2924
# Epoch 55/100 Validation Accuracy: 91.64%
# --------------------------------------------------
# Epoch 56/100
# Epoch 56/100 Training Loss: 0.2676
# Epoch 56/100 Training Accuracy: 92.43%
# Epoch 56/100 Validation Loss: 0.2892
# Epoch 56/100 Validation Accuracy: 91.78%
# --------------------------------------------------
# Epoch 57/100
# Epoch 57/100 Training Loss: 0.2678
# Epoch 57/100 Training Accuracy: 92.43%
# Epoch 57/100 Validation Loss: 0.2898
# Epoch 57/100 Validation Accuracy: 91.87%
# --------------------------------------------------
# Epoch 58/100
# Epoch 58/100 Training Loss: 0.2668
# Epoch 58/100 Training Accuracy: 92.41%
# Epoch 58/100 Validation Loss: 0.2924
# Epoch 58/100 Validation Accuracy: 91.56%
# --------------------------------------------------
# Epoch 59/100
# Epoch 59/100 Training Loss: 0.2675
# Epoch 59/100 Training Accuracy: 92.41%
# Epoch 59/100 Validation Loss: 0.2910
# Epoch 59/100 Validation Accuracy: 91.69%
# --------------------------------------------------
# Epoch 60/100
# Epoch 60/100 Training Loss: 0.2665
# Epoch 60/100 Training Accuracy: 92.46%
# Epoch 60/100 Validation Loss: 0.2901
# Epoch 60/100 Validation Accuracy: 91.85%
# --------------------------------------------------
# Epoch 61/100
# Epoch 61/100 Training Loss: 0.2654
# Epoch 61/100 Training Accuracy: 92.51%
# Epoch 61/100 Validation Loss: 0.2914
# Epoch 61/100 Validation Accuracy: 91.63%
# --------------------------------------------------
# Epoch 62/100
# Epoch 62/100 Training Loss: 0.2651
# Epoch 62/100 Training Accuracy: 92.44%
# Epoch 62/100 Validation Loss: 0.2893
# Epoch 62/100 Validation Accuracy: 91.70%
# --------------------------------------------------
# Epoch 63/100
# Epoch 63/100 Training Loss: 0.2652
# Epoch 63/100 Training Accuracy: 92.45%
# Epoch 63/100 Validation Loss: 0.2947
# Epoch 63/100 Validation Accuracy: 91.52%
# --------------------------------------------------
# Epoch 64/100
# Epoch 64/100 Training Loss: 0.2661
# Epoch 64/100 Training Accuracy: 92.56%
# Epoch 64/100 Validation Loss: 0.2907
# Epoch 64/100 Validation Accuracy: 91.70%
# --------------------------------------------------
# Epoch 65/100
# Epoch 65/100 Training Loss: 0.2640
# Epoch 65/100 Training Accuracy: 92.53%
# Epoch 65/100 Validation Loss: 0.2877
# Epoch 65/100 Validation Accuracy: 91.89%
# --------------------------------------------------
# Epoch 66/100
# Epoch 66/100 Training Loss: 0.2640
# Epoch 66/100 Training Accuracy: 92.56%
# Epoch 66/100 Validation Loss: 0.2893
# Epoch 66/100 Validation Accuracy: 91.85%
# --------------------------------------------------
# Epoch 67/100
# Epoch 67/100 Training Loss: 0.2633
# Epoch 67/100 Training Accuracy: 92.54%
# Epoch 67/100 Validation Loss: 0.2905
# Epoch 67/100 Validation Accuracy: 91.62%
# --------------------------------------------------
# Epoch 68/100
# Epoch 68/100 Training Loss: 0.2632
# Epoch 68/100 Training Accuracy: 92.55%
# Epoch 68/100 Validation Loss: 0.2903
# Epoch 68/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 69/100
# Epoch 69/100 Training Loss: 0.2642
# Epoch 69/100 Training Accuracy: 92.60%
# Epoch 69/100 Validation Loss: 0.2881
# Epoch 69/100 Validation Accuracy: 91.82%
# --------------------------------------------------
# Epoch 70/100
# Epoch 70/100 Training Loss: 0.2635
# Epoch 70/100 Training Accuracy: 92.63%
# Epoch 70/100 Validation Loss: 0.2884
# Epoch 70/100 Validation Accuracy: 91.97%
# --------------------------------------------------
# Epoch 71/100
# Epoch 71/100 Training Loss: 0.2622
# Epoch 71/100 Training Accuracy: 92.58%
# Epoch 71/100 Validation Loss: 0.2887
# Epoch 71/100 Validation Accuracy: 91.71%
# --------------------------------------------------
# Epoch 72/100
# Epoch 72/100 Training Loss: 0.2618
# Epoch 72/100 Training Accuracy: 92.61%
# Epoch 72/100 Validation Loss: 0.2884
# Epoch 72/100 Validation Accuracy: 91.81%
# --------------------------------------------------
# Epoch 73/100
# Epoch 73/100 Training Loss: 0.2615
# Epoch 73/100 Training Accuracy: 92.58%
# Epoch 73/100 Validation Loss: 0.2865
# Epoch 73/100 Validation Accuracy: 91.99%
# --------------------------------------------------
# Epoch 74/100
# Epoch 74/100 Training Loss: 0.2610
# Epoch 74/100 Training Accuracy: 92.64%
# Epoch 74/100 Validation Loss: 0.2949
# Epoch 74/100 Validation Accuracy: 91.49%
# --------------------------------------------------
# Epoch 75/100
# Epoch 75/100 Training Loss: 0.2614
# Epoch 75/100 Training Accuracy: 92.64%
# Epoch 75/100 Validation Loss: 0.2874
# Epoch 75/100 Validation Accuracy: 91.84%
# --------------------------------------------------
# Epoch 76/100
# Epoch 76/100 Training Loss: 0.2611
# Epoch 76/100 Training Accuracy: 92.62%
# Epoch 76/100 Validation Loss: 0.2926
# Epoch 76/100 Validation Accuracy: 91.69%
# --------------------------------------------------
# Epoch 77/100
# Epoch 77/100 Training Loss: 0.2613
# Epoch 77/100 Training Accuracy: 92.60%
# Epoch 77/100 Validation Loss: 0.2892
# Epoch 77/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 78/100
# Epoch 78/100 Training Loss: 0.2605
# Epoch 78/100 Training Accuracy: 92.63%
# Epoch 78/100 Validation Loss: 0.2889
# Epoch 78/100 Validation Accuracy: 91.77%
# --------------------------------------------------
# Epoch 79/100
# Epoch 79/100 Training Loss: 0.2598
# Epoch 79/100 Training Accuracy: 92.64%
# Epoch 79/100 Validation Loss: 0.2851
# Epoch 79/100 Validation Accuracy: 91.94%
# --------------------------------------------------
# Epoch 80/100
# Epoch 80/100 Training Loss: 0.2597
# Epoch 80/100 Training Accuracy: 92.65%
# Epoch 80/100 Validation Loss: 0.2867
# Epoch 80/100 Validation Accuracy: 91.94%
# --------------------------------------------------
# Epoch 81/100
# Epoch 81/100 Training Loss: 0.2591
# Epoch 81/100 Training Accuracy: 92.66%
# Epoch 81/100 Validation Loss: 0.2865
# Epoch 81/100 Validation Accuracy: 91.86%
# --------------------------------------------------
# Epoch 82/100
# Epoch 82/100 Training Loss: 0.2599
# Epoch 82/100 Training Accuracy: 92.73%
# Epoch 82/100 Validation Loss: 0.2933
# Epoch 82/100 Validation Accuracy: 91.76%
# --------------------------------------------------
# Epoch 83/100
# Epoch 83/100 Training Loss: 0.2594
# Epoch 83/100 Training Accuracy: 92.63%
# Epoch 83/100 Validation Loss: 0.2856
# Epoch 83/100 Validation Accuracy: 91.92%
# --------------------------------------------------
# Epoch 84/100
# Epoch 84/100 Training Loss: 0.2586
# Epoch 84/100 Training Accuracy: 92.69%
# Epoch 84/100 Validation Loss: 0.2868
# Epoch 84/100 Validation Accuracy: 91.96%
# --------------------------------------------------
# Epoch 85/100
# Epoch 85/100 Training Loss: 0.2581
# Epoch 85/100 Training Accuracy: 92.70%
# Epoch 85/100 Validation Loss: 0.2867
# Epoch 85/100 Validation Accuracy: 91.89%
# --------------------------------------------------
# Epoch 86/100
# Epoch 86/100 Training Loss: 0.2590
# Epoch 86/100 Training Accuracy: 92.70%
# Epoch 86/100 Validation Loss: 0.2871
# Epoch 86/100 Validation Accuracy: 91.81%
# --------------------------------------------------
# Epoch 87/100
# Epoch 87/100 Training Loss: 0.2581
# Epoch 87/100 Training Accuracy: 92.71%
# Epoch 87/100 Validation Loss: 0.2915
# Epoch 87/100 Validation Accuracy: 91.89%
# --------------------------------------------------
# Epoch 88/100
# Epoch 88/100 Training Loss: 0.2579
# Epoch 88/100 Training Accuracy: 92.70%
# Epoch 88/100 Validation Loss: 0.2857
# Epoch 88/100 Validation Accuracy: 91.99%
# --------------------------------------------------
# Epoch 89/100
# Epoch 89/100 Training Loss: 0.2576
# Epoch 89/100 Training Accuracy: 92.67%
# Epoch 89/100 Validation Loss: 0.2889
# Epoch 89/100 Validation Accuracy: 91.70%
# --------------------------------------------------
# Epoch 90/100
# Epoch 90/100 Training Loss: 0.2572
# Epoch 90/100 Training Accuracy: 92.75%
# Epoch 90/100 Validation Loss: 0.2871
# Epoch 90/100 Validation Accuracy: 91.94%
# --------------------------------------------------
# Epoch 91/100
# Epoch 91/100 Training Loss: 0.2566
# Epoch 91/100 Training Accuracy: 92.80%
# Epoch 91/100 Validation Loss: 0.2844
# Epoch 91/100 Validation Accuracy: 92.04%
# --------------------------------------------------
# Epoch 92/100
# Epoch 92/100 Training Loss: 0.2564
# Epoch 92/100 Training Accuracy: 92.71%
# Epoch 92/100 Validation Loss: 0.2851
# Epoch 92/100 Validation Accuracy: 91.90%
# --------------------------------------------------
# Epoch 93/100
# Epoch 93/100 Training Loss: 0.2563
# Epoch 93/100 Training Accuracy: 92.76%
# Epoch 93/100 Validation Loss: 0.2853
# Epoch 93/100 Validation Accuracy: 91.89%
# --------------------------------------------------
# Epoch 94/100
# Epoch 94/100 Training Loss: 0.2574
# Epoch 94/100 Training Accuracy: 92.79%
# Epoch 94/100 Validation Loss: 0.2873
# Epoch 94/100 Validation Accuracy: 92.09%
# --------------------------------------------------
# Epoch 95/100
# Epoch 95/100 Training Loss: 0.2564
# Epoch 95/100 Training Accuracy: 92.82%
# Epoch 95/100 Validation Loss: 0.2842
# Epoch 95/100 Validation Accuracy: 92.09%
# --------------------------------------------------
# Epoch 96/100
# Epoch 96/100 Training Loss: 0.2563
# Epoch 96/100 Training Accuracy: 92.73%
# Epoch 96/100 Validation Loss: 0.2867
# Epoch 96/100 Validation Accuracy: 91.99%
# --------------------------------------------------
# Epoch 97/100
# Epoch 97/100 Training Loss: 0.2553
# Epoch 97/100 Training Accuracy: 92.79%
# Epoch 97/100 Validation Loss: 0.2847
# Epoch 97/100 Validation Accuracy: 92.10%
# --------------------------------------------------
# Epoch 98/100
# Epoch 98/100 Training Loss: 0.2559
# Epoch 98/100 Training Accuracy: 92.85%
# Epoch 98/100 Validation Loss: 0.2843
# Epoch 98/100 Validation Accuracy: 92.02%
# --------------------------------------------------
# Epoch 99/100
# Epoch 99/100 Training Loss: 0.2553
# Epoch 99/100 Training Accuracy: 92.85%
# Epoch 99/100 Validation Loss: 0.2863
# Epoch 99/100 Validation Accuracy: 92.01%
# --------------------------------------------------
# Epoch 100/100
# Epoch 100/100 Training Loss: 0.2549
# Epoch 100/100 Training Accuracy: 92.74%
# Epoch 100/100 Validation Loss: 0.2834
# Epoch 100/100 Validation Accuracy: 91.98%
# --------------------------------------------------
# Training time for learning rate 0.01: 1490.23 seconds with L2 regularization
# Test Accuracy: 91.79% for learning rate: 0.01 with L2 regularization
# --------------------------------------------------
# Results Summary for learning rate:  0.01  with L2 regularization
# Training Loss:  0.2549
# Training Accuracy:  92.7429%
# Validation Loss:  0.2834
# Validation Accuracy:  91.9786%
# Test Accuracy: 91.79%
# Total Training Time: 1490.23 seconds
# --------------------------------------------------

# %% [markdown]
# <h2>Results Summary</h2>

# %%
print("Final Results for all learning rates with L2 Reqularization:")
for lr in [0.01]:
    print(f"learning_rate = {lr}")
    print(f"Training Loss: {dict[lr][0]: .4f}")
    print(f"Training Accuracy: {dict[lr][1]: .4f}%")
    print(f"Validation Loss: {dict[lr][2]: .4f}")
    print(f"Validation Accuracy: {dict[lr][3]: .4f}%")
    print(f"Test Accuracy: {results[lr]['test_accuracy']:.2f}%")
    print(f"Total Training Time: {results[lr]['total_duration']:.2f} seconds")

    print("-" * 50)
# Out:
# Final Results for all learning rates with L2 Reqularization:
# learning_rate = 0.01
# Training Loss:  0.2549
# Training Accuracy:  92.7429%
# Validation Loss:  0.2834
# Validation Accuracy:  91.9786%
# Test Accuracy: 91.79%
# Total Training Time: 1490.23 seconds
# --------------------------------------------------

# %% [markdown]
# <h2>Best Learning Rate</h2>

# %%
# Find the best learning rate based on the test accuracy
best_lr = None
best_accuracy = 0

for lr in results.keys():
    if results[lr]['test_accuracy'] > best_accuracy:
        best_accuracy = results[lr]['test_accuracy']
        best_lr = lr

print(f"Best Learning Rate: {best_lr} with Test Accuracy: {best_accuracy:.2f}% with L2 regularization")
# Out:
# Best Learning Rate: 0.01 with Test Accuracy: 91.79% with L2 regularization
